# %%
import pandas as pd

# %%
#Take in data as a dataframe for easy preprocessing
total_df = pd.read_excel('/Users/wesleytatum/Desktop/OPV_total_df.xlsx')
print (total_df.shape)
total_df.head()
# Out:
# (108, 20)
#    Unnamed: 0  Anneal_time  Anneal_temp  Substrate  Device  MajorAL_avg  \
# 0           0           15          100          4       2    17.194652
# 1           1           15          100          4       4    13.709728
# 2           2           15          100          4       7    18.211098
# 3           3           30          100          7       2    19.640309
# 4           4           30          100          7       4    20.647291
#
#    MajorAL_stdev  MinorAL_avg  MinorAL_stdev   Ecc_avg  Ecc_stdev  Orient_avg  \
# 0      29.172066     8.554721      14.246681  0.820518   0.142370   -0.050137
# 1      14.635628     6.938374       7.985216  0.824877   0.138410   -0.205623
# 2      21.013541     8.857453      10.356933  0.826205   0.148190   -0.414390
# 3      46.935628     9.781374      26.994708  0.857443   0.105577   -0.331902
# 4      35.791550     8.412561      11.216702  0.833485   0.136928   -0.454930
#
#    Orient_stdev   Perim_avg  Perim_stdev  GMM_label       PCE      VocL  \
# 0      1.067225   97.003245   352.677591          1  2.311387  0.577792
# 1      1.075388   48.559552    98.492589          1  1.763230  0.522596
# 2      1.047842   75.736366   151.456627          1  2.394418  0.575790
# 3      0.940640  236.482362  1306.085256          1  2.628197  0.569525
# 4      0.862964   96.093361   315.148913          1  2.710602  0.568631
#
#         Jsc        FF
# 0  6.963861  57.44484
# 1  7.047848  47.87256
# 2  6.939877  59.92170
# 3  7.301575  63.20169
# 4  7.328048  65.04993

# %%
X = total_df[['Anneal_time', 'Anneal_temp', 'MajorAL_avg', 'MajorAL_stdev', 'MinorAL_avg',
              'MinorAL_stdev', 'Ecc_avg', 'Ecc_stdev', 'Orient_avg', 'Orient_stdev', 'Perim_avg',
              'Perim_stdev', 'GMM_label']] #input features used to make prediction
Y = total_df[['PCE', 'VocL', 'Jsc', 'FF']] #target features to be predicted

# %%
x,y = X.shape

normed_X = pd.DataFrame()

X_norm_key = {}

for colname, coldata in X.iteritems():
    max_val = coldata.max()
    min_val = coldata.min()
    
    X_norm_key[colname] = [min_val, max_val]
    
    normed_col = (coldata - min_val) / (max_val - min_val)
    normed_X[colname] = normed_col
    
print (X_norm_key)
normed_X.head()
# Out:
# {'Anneal_time': [0, 30], 'Anneal_temp': [0, 175], 'MajorAL_avg': [6.795627420493405, 63.49794295512363], 'MajorAL_stdev': [4.831675109751423, 53.25040367180645], 'MinorAL_avg': [2.408932835444501, 23.73775125472676], 'MinorAL_stdev': [1.669156645291437, 26.99470790181131], 'Ecc_avg': [0.7889272986656537, 0.9458829456955873], 'Ecc_stdev': [0.07223066065028902, 0.1697737861511331], 'Orient_avg': [-0.630199541048445, 0.44657266717009], 'Orient_stdev': [0.2391626788046514, 1.414746984159737], 'Perim_avg': [12.75742732040717, 249.5834435261197], 'Perim_stdev': [12.23542518184645, 1422.994117629404], 'GMM_label': [1, 3]}
#    Anneal_time  Anneal_temp  MajorAL_avg  MajorAL_stdev  MinorAL_avg  \
# 0          0.5     0.571429     0.183397       0.502706     0.288145
# 1          0.5     0.571429     0.121937       0.202483     0.212363
# 2          0.5     0.571429     0.201323       0.334207     0.302338
# 3          1.0     0.571429     0.226528       0.869580     0.345656
# 4          1.0     0.571429     0.244287       0.639419     0.281480
#
#    MinorAL_stdev   Ecc_avg  Ecc_stdev  Orient_avg  Orient_stdev  Perim_avg  \
# 0       0.496634  0.201270   0.719059    0.538705      0.704384   0.355729
# 1       0.249395  0.229047   0.678461    0.394305      0.711328   0.151175
# 2       0.343044  0.237506   0.778727    0.200423      0.687896   0.265929
# 3       1.000000  0.436532   0.341864    0.277029      0.596705   0.944681
# 4       0.376993  0.283890   0.663273    0.162774      0.530631   0.351887
#
#    Perim_stdev  GMM_label
# 0     0.241318        0.0
# 1     0.061142        0.0
# 2     0.098685        0.0
# 3     0.917131        0.0
# 4     0.214717        0.0

# %%
def df_normalizer(dataframe):
    
    df = dataframe
    
    normed_df = pd.DataFrame()

    df_norm_key = {}

    for colname, coldata in df.iteritems():
        max_val = coldata.max()
        min_val = coldata.min()

        df_norm_key[colname] = [min_val, max_val]

        normed_col = (coldata - min_val) / (max_val - min_val)
        normed_df[colname] = normed_col
        
    return normed_df, df_norm_key

# %%
df, key = df_normalizer(X)

print (key)
df.head()
# Out:
# {'Anneal_time': [0, 30], 'Anneal_temp': [0, 175], 'MajorAL_avg': [6.795627420493405, 63.49794295512363], 'MajorAL_stdev': [4.831675109751423, 53.25040367180645], 'MinorAL_avg': [2.408932835444501, 23.73775125472676], 'MinorAL_stdev': [1.669156645291437, 26.99470790181131], 'Ecc_avg': [0.7889272986656537, 0.9458829456955873], 'Ecc_stdev': [0.07223066065028902, 0.1697737861511331], 'Orient_avg': [-0.630199541048445, 0.44657266717009], 'Orient_stdev': [0.2391626788046514, 1.414746984159737], 'Perim_avg': [12.75742732040717, 249.5834435261197], 'Perim_stdev': [12.23542518184645, 1422.994117629404], 'GMM_label': [1, 3]}
#    Anneal_time  Anneal_temp  MajorAL_avg  MajorAL_stdev  MinorAL_avg  \
# 0          0.5     0.571429     0.183397       0.502706     0.288145
# 1          0.5     0.571429     0.121937       0.202483     0.212363
# 2          0.5     0.571429     0.201323       0.334207     0.302338
# 3          1.0     0.571429     0.226528       0.869580     0.345656
# 4          1.0     0.571429     0.244287       0.639419     0.281480
#
#    MinorAL_stdev   Ecc_avg  Ecc_stdev  Orient_avg  Orient_stdev  Perim_avg  \
# 0       0.496634  0.201270   0.719059    0.538705      0.704384   0.355729
# 1       0.249395  0.229047   0.678461    0.394305      0.711328   0.151175
# 2       0.343044  0.237506   0.778727    0.200423      0.687896   0.265929
# 3       1.000000  0.436532   0.341864    0.277029      0.596705   0.944681
# 4       0.376993  0.283890   0.663273    0.162774      0.530631   0.351887
#
#    Perim_stdev  GMM_label
# 0     0.241318        0.0
# 1     0.061142        0.0
# 2     0.098685        0.0
# 3     0.917131        0.0
# 4     0.214717        0.0

# %%
def df_denormalize(normed_df, norm_key):
    
    denormed_df = pd.DataFrame()
    
    for colname, coldata in normed_df.iteritems():
        mn = norm_key[colname][0]
        mx = norm_key[colname][1]
        
        denormed_col = (coldata * (mx - mn)) + mn
        
        denormed_df[colname] = denormed_col
        
    return denormed_df

# %%
test = df_denormalize(df, key)

test.head()
# Out:
#    Anneal_time  Anneal_temp  MajorAL_avg  MajorAL_stdev  MinorAL_avg  \
# 0         15.0        100.0    17.194652      29.172066     8.554721
# 1         15.0        100.0    13.709728      14.635628     6.938374
# 2         15.0        100.0    18.211098      21.013541     8.857453
# 3         30.0        100.0    19.640309      46.935628     9.781374
# 4         30.0        100.0    20.647291      35.791550     8.412561
#
#    MinorAL_stdev   Ecc_avg  Ecc_stdev  Orient_avg  Orient_stdev   Perim_avg  \
# 0      14.246681  0.820518   0.142370   -0.050137      1.067225   97.003245
# 1       7.985216  0.824877   0.138410   -0.205623      1.075388   48.559552
# 2      10.356933  0.826205   0.148190   -0.414390      1.047842   75.736366
# 3      26.994708  0.857443   0.105577   -0.331902      0.940640  236.482362
# 4      11.216702  0.833485   0.136928   -0.454930      0.862964   96.093361
#
#    Perim_stdev  GMM_label
# 0   352.677591        1.0
# 1    98.492589        1.0
# 2   151.456627        1.0
# 3  1306.085256        1.0
# 4   315.148913        1.0
