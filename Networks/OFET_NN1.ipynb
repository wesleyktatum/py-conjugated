# %%
# %load_ext autoreload

import os
import sys
import glob

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

import torch
import torch.nn as nn

module_path = os.path.abspath(os.path.join('../m2py/networks/'))
if module_path not in sys.path:
    sys.path.append(module_path)
import morphology_networks as net
import model_training as train
import model_testing as test
import physically_informed_loss_functions as PhysLoss
import network_utils as nuts

torch.manual_seed(28)

# %% [markdown]
# # This notebook seeks to use all OFET processing conditions and morphological descriptors to predict device performance.
#
# ## There will be 3 Neural Networks outlined, each with similar architecture, but varying inputs. This first NN will only use processing conditions to try to predict performance
#
# ### Inputs:
# - DataFrame containing device processing conditions and their subsequent performance.
#
# *_Note:_* This DataFrame will only contain devices with reasonable performance values.
#
# ### Outputs:
# - Tensor of predicted performance for given processing conditions

# %%
#Take in data as a dataframe for easy preprocessing
device_df = pd.read_excel('/Users/wesleytatum/Desktop/OFET_device_df.xlsx')
print (device_df.shape)
device_df.head()
# Out:
# (80, 15)
#    Unnamed: 0  Unnamed: 0.1                   Sample  Temperature  Time  \
# 0           0             0  75C-5min_1-IdVg-2-Vd-20           75     5
# 1           1             1  75C-5min_1-IdVg-4-Vd-20           75     5
# 2           2             2  75C-5min_2-IdVg-1-Vd-20           75     5
# 3           3             3  75C-5min_2-IdVg-3-Vd-20           75     5
# 4           4             4  75C-5min_2-IdVg-4-Vd-20           75     5
#
#    Substrate  Device  mu_lin_avg  mu_lin_SD  r_lin_avg  r_lin_sd   on_off_avg  \
# 0          1       2    0.002176   0.000014   0.580171  0.013437  1119.582374
# 1          1       4    0.004906   0.000259   0.551756  0.020972   892.258038
# 2          2       1    0.004643   0.000015   0.557327  0.002400    20.595284
# 3          2       3    0.012977   0.002372   0.581325  0.004444   619.347250
# 4          2       4    0.010087   0.000050   0.585769  0.006963  1812.113114
#
#      on_off_sd     Vt_avg     Vt_sd
# 0    30.715757 -31.511376  0.198134
# 1     4.484375 -28.971871  0.461514
# 2     0.172757 -18.556867  0.166910
# 3  1024.656122 -21.054614  1.348128
# 4    15.685197 -19.170370  0.165707

# %%
# Hyper parameters
num_epochs = 100
batch_size = int(len(device_df['mu_lin_avg'])*0.8*0.5) # 90% of x_train samples
learning_rate = 0.000095

# Device configuration (GPU if available, otherwise CPU)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
X = device_df[['Time', 'Temperature']] #input features used to make prediction
Y = device_df[['mu_lin_avg', 'r_lin_avg', 'on_off_avg', 'Vt_avg']] #target features to be predicted

x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, shuffle = True) #split dataset into separate testing and training datasets

# %%
# %autoreload

x_train, x_train_key = nuts.df_Gaussian_normalize(x_train)
y_train, y_train_key = nuts.df_Gaussian_normalize(y_train)

x_test, x_test_key = nuts.df_Gaussian_normalize(x_test)
y_test, y_test_key = nuts.df_Gaussian_normalize(y_test)

mu_train = y_train['mu_lin_avg']
mu_test = y_test['mu_lin_avg']
r_train = y_train['r_lin_avg']
r_test = y_test['r_lin_avg']
on_off_train = y_train['on_off_avg']
on_off_test = y_test['on_off_avg']
vt_train = y_train['Vt_avg']
vt_test = y_test['Vt_avg']

x_train_tensor = torch.tensor(x_train.values.astype(np.float32)) #convert pd.DataFrame -> np.ndarray -> torch.tensor
mu_train_tensor = torch.tensor(mu_train.values.astype(np.float32))
r_train_tensor = torch.tensor(r_train.values.astype(np.float32))
on_off_train_tensor = torch.tensor(on_off_train.values.astype(np.float32))
vt_train_tensor = torch.tensor(vt_train.values.astype(np.float32))
train_tensor = torch.utils.data.TensorDataset(x_train_tensor, mu_train_tensor,
                                              r_train_tensor, on_off_train_tensor,
                                              vt_train_tensor) #create tensor with features and targets
training_data_set = torch.utils.data.DataLoader(dataset = train_tensor, batch_size = batch_size, shuffle = True, drop_last = True) #create iterable dataset with batches

x_test_tensor = torch.tensor(x_test.values.astype(np.float32))
mu_test_tensor = torch.tensor(mu_test.values.astype(np.float32))
r_test_tensor = torch.tensor(r_test.values.astype(np.float32))
on_off_test_tensor = torch.tensor(on_off_test.values.astype(np.float32))
vt_test_tensor = torch.tensor(vt_test.values.astype(np.float32))
test_tensor = torch.utils.data.TensorDataset(x_test_tensor, mu_test_tensor,
                                              r_test_tensor, on_off_test_tensor,
                                              vt_test_tensor)
testing_data_set = torch.utils.data.DataLoader(dataset = test_tensor, batch_size = batch_size, shuffle = True)

# %% [markdown]
# Now that the data, model, training, and evaluating are all set up, let's actually use everything

# %%
# Instantiate our beautiful NN model
# takes in 2 features (anneal time, anneal temp) 
# predicts 4 metrics (mu_lin, r_lin, on_off, Vt)
in_dims = int(x_train_tensor.size(1)) #number of x channels
out_dims = y_test.shape[1] #number of predicted features

model = net.OFET_df_NN(in_dims = in_dims, out_dims = out_dims).to(device)
model.apply(nuts.init_weights)

#define the optimizer
optimizer = torch.optim.Adam(params = model.parameters(), lr = learning_rate)

# %%
# %autoreload

#empty list to hold loss per epoch
train_epoch_losses = []
mu_train_epoch_losses = []
r_train_epoch_losses = []
on_off_train_epoch_losses = []
vt_train_epoch_losses = []

test_epoch_losses = []
mu_test_epoch_losses = []
r_test_epoch_losses = []
on_off_test_epoch_losses = []
vt_test_epoch_losses = []

mu_test_epoch_accuracies = []
r_test_epoch_accuracies = []
on_off_test_epoch_accuracies = []
vt_test_epoch_accuracies = []

save_epochs = np.arange(0, num_epochs, 5)

for epoch in range(num_epochs):
    print('On epoch ', epoch)
    
    save_dir = "/Users/wesleytatum/Desktop/model_states/OFET_NN1/"
    model_name = "OFET_NN1"
    model_path = save_dir+model_name+'*.pt'
    if epoch < 10:
        save_path = save_dir + model_name + '_epoch0' + str(epoch) + '.pt'
    else:
        save_path = save_dir + model_name + '_epoch' + str(epoch) + '.pt'
        
#     if glob.glob(model_path) != []:
#         model_states = glob.glob(model_path)
#         model_states = sorted(model_states)
#         previous_model = model_states[-1]
        
#         model, optimizer = nuts.load_trained_model(previous_model, model, optimizer)
    
    model, train_loss, mu_train_loss, r_train_loss, on_off_train_loss, vt_train_loss = train.train_OFET_df_model(model = model,
                                                                                                                 training_data_set = training_data_set,
                                                                                                                 optimizer = optimizer)
    train_epoch_losses.append(train_loss)
    mu_train_epoch_losses.append(mu_train_loss)
    r_train_epoch_losses.append(r_train_loss)
    on_off_train_epoch_losses.append(on_off_train_loss)
    vt_train_epoch_losses.append(vt_train_loss)
    
    test_loss, mu_test_loss, r_test_loss, on_off_test_loss, vt_test_loss, mu_acc, r_acc, on_off_acc, vt_acc = test.eval_OFET_df_model(model = model,
                                                                                                                                      testing_data_set = testing_data_set)
    test_epoch_losses.append(test_loss)
    mu_test_epoch_losses.append(mu_test_loss)
    r_test_epoch_losses.append(r_test_loss)
    on_off_test_epoch_losses.append(on_off_test_loss)
    vt_test_epoch_losses.append(vt_test_loss)
    
    mu_test_epoch_accuracies.append(mu_acc)
    r_test_epoch_accuracies.append(r_acc)
    on_off_test_epoch_accuracies.append(on_off_acc)
    vt_test_epoch_accuracies.append(vt_acc)
    
    if epoch in save_epochs:
 
        nuts.save_trained_model(save_path, epoch, model, optimizer, train_loss, test_loss)
        #TODO: update for branched OPV specific function?
# Out:
# On epoch  0
# Total Epoch Testing Loss = 0.2966170310974121
# Total Epoch Testing Accuracy: mu = -32.594192028045654
#                               r = 37.022965773940086
#                               on_off = -122.8469368070364
#                               Vt = -48.31446558237076
# On epoch  1
# Total Epoch Testing Loss = 0.1605721116065979
# Total Epoch Testing Accuracy: mu = -27.871350944042206
#                               r = 37.5
#                               on_off = -119.04167234897614
#                               Vt = -47.09825627505779
# On epoch  2
# Total Epoch Testing Loss = 0.2894200086593628
# Total Epoch Testing Accuracy: mu = -24.911857396364212
#                               r = 37.5
#                               on_off = -116.40098728239536
#                               Vt = -45.96628248691559
# On epoch  3
# Total Epoch Testing Loss = 0.2863604724407196
# Total Epoch Testing Accuracy: mu = -22.73470088839531
#                               r = 37.494418397545815
#                               on_off = -113.85483928024769
#                               Vt = -44.98749598860741
# On epoch  4
# Total Epoch Testing Loss = 0.04321243241429329
# Total Epoch Testing Accuracy: mu = -21.943406388163567
#                               r = 37.39519491791725
#                               on_off = -112.74562031030655
#                               Vt = -43.69695484638214
# On epoch  5
# Total Epoch Testing Loss = 0.1600922793149948
# Total Epoch Testing Accuracy: mu = -22.808033972978592
#                               r = 37.193235382437706
#                               on_off = -108.36987122893333
#                               Vt = -43.04343797266483
# On epoch  6
# Total Epoch Testing Loss = 0.03602641075849533
# Total Epoch Testing Accuracy: mu = -23.12578670680523
#                               r = 36.528338864445686
#                               on_off = -106.23547397553921
#                               Vt = -42.704859003424644
# On epoch  7
# Total Epoch Testing Loss = 0.43362054228782654
# Total Epoch Testing Accuracy: mu = -22.755926474928856
#                               r = 35.75700558722019
#                               on_off = -104.7982219606638
#                               Vt = -42.380910739302635
# On epoch  8
# Total Epoch Testing Loss = 0.43358153104782104
# Total Epoch Testing Accuracy: mu = -23.597627878189087
#                               r = 35.214365273714066
#                               on_off = -104.28996197879314
#                               Vt = -42.18457341194153
# On epoch  9
# /Users/wesleytatum/Desktop/m2py/m2py_Github/m2py/m2py/networks/physically_informed_loss_functions.py:120: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   error = torch.neg(torch.tensor(y))
# Total Epoch Testing Loss = 0.1295367181301117
# Total Epoch Testing Accuracy: mu = -24.444876238703728
#                               r = 34.71645377576351
#                               on_off = -104.1273508220911
#                               Vt = -42.36289598047733
# On epoch  10
# Total Epoch Testing Loss = 0.1926262229681015
# Total Epoch Testing Accuracy: mu = -25.382959097623825
#                               r = 34.4017643481493
#                               on_off = -105.29447458684444
#                               Vt = -42.45675429701805
# On epoch  11
# Total Epoch Testing Loss = 0.19909042119979858
# Total Epoch Testing Accuracy: mu = -26.313645858317614
#                               r = 34.08857434988022
#                               on_off = -104.65901307761669
#                               Vt = -42.60629191994667
# On epoch  12
# Total Epoch Testing Loss = 0.05927528068423271
# Total Epoch Testing Accuracy: mu = -27.226752135902643
#                               r = 33.798910304903984
#                               on_off = -103.5730890929699
#                               Vt = -42.95100308954716
# On epoch  13
# Total Epoch Testing Loss = 0.053461141884326935
# Total Epoch Testing Accuracy: mu = -27.67138318158686
#                               r = 33.510540053248405
#                               on_off = -104.28242608904839
#                               Vt = -43.52766536176205
# On epoch  14
# Total Epoch Testing Loss = 0.9227637648582458
# Total Epoch Testing Accuracy: mu = -27.858260506764054
#                               r = 33.15639682114124
#                               on_off = -105.85573427379131
#                               Vt = -43.79216954112053
# On epoch  15
# Total Epoch Testing Loss = 0.42135244607925415
# Total Epoch Testing Accuracy: mu = -27.163818292319775
#                               r = 32.73204825818539
#                               on_off = -106.69634565711021
#                               Vt = -44.211896508932114
# On epoch  16
# Total Epoch Testing Loss = 0.5055962204933167
# Total Epoch Testing Accuracy: mu = -25.936901196837425
#                               r = 32.33705870807171
#                               on_off = -108.19605030119419
#                               Vt = -44.76592540740967
# On epoch  17
# Total Epoch Testing Loss = 0.1391788125038147
# Total Epoch Testing Accuracy: mu = -25.247859209775925
#                               r = 31.77444338798523
#                               on_off = -110.13589799404144
#                               Vt = -45.01628428697586
# On epoch  18
# Total Epoch Testing Loss = 0.06964456290006638
# Total Epoch Testing Accuracy: mu = -25.89535228908062
#                               r = 30.998384580016136
#                               on_off = -111.96452789008617
#                               Vt = -45.1742947101593
# On epoch  19
# Total Epoch Testing Loss = 0.418071985244751
# Total Epoch Testing Accuracy: mu = -24.514880403876305
#                               r = 30.44571839272976
#                               on_off = -113.74158002436161
#                               Vt = -45.56983597576618
# On epoch  20
# Total Epoch Testing Loss = 0.20232245326042175
# Total Epoch Testing Accuracy: mu = -23.350051790475845
#                               r = 30.095448344945908
#                               on_off = -115.96832685172558
#                               Vt = -46.04485705494881
# On epoch  21
# Total Epoch Testing Loss = 0.0582999661564827
# Total Epoch Testing Accuracy: mu = -22.930023074150085
#                               r = 29.891384579241276
#                               on_off = -118.74014772474766
#                               Vt = -46.591392531991005
# On epoch  22
# Total Epoch Testing Loss = 0.29272180795669556
# Total Epoch Testing Accuracy: mu = -21.870767325162888
#                               r = 29.306910187005997
#                               on_off = -120.59112451970577
#                               Vt = -47.12318629026413
# On epoch  23
# Total Epoch Testing Loss = 0.20376738905906677
# Total Epoch Testing Accuracy: mu = -20.62632106244564
#                               r = 29.281121864914894
#                               on_off = -122.43702635169029
#                               Vt = -47.816454619169235
# On epoch  24
# Total Epoch Testing Loss = 0.29365819692611694
# Total Epoch Testing Accuracy: mu = -18.46308894455433
#                               r = 28.870798461139202
#                               on_off = -124.91124346852303
#                               Vt = -48.44862148165703
# On epoch  25
# Total Epoch Testing Loss = 0.06937278062105179
# Total Epoch Testing Accuracy: mu = -17.230205610394478
#                               r = 28.22519578039646
#                               on_off = -127.74525880813599
#                               Vt = -48.863332346081734
# On epoch  26
# Total Epoch Testing Loss = 0.26145240664482117
# Total Epoch Testing Accuracy: mu = -14.865236356854439
#                               r = 27.45579620823264
#                               on_off = -131.60387724637985
#                               Vt = -49.0071140229702
# On epoch  27
# Total Epoch Testing Loss = 0.2983177900314331
# Total Epoch Testing Accuracy: mu = -12.584392726421356
#                               r = 27.375765796750784
#                               on_off = -134.4824679195881
#                               Vt = -48.8294068723917
# On epoch  28
# Total Epoch Testing Loss = 0.06573300063610077
# Total Epoch Testing Accuracy: mu = -11.655239388346672
#                               r = 27.325844205915928
#                               on_off = -138.62957321107388
#                               Vt = -48.8488607108593
# On epoch  29
# Total Epoch Testing Loss = 0.12358687818050385
# Total Epoch Testing Accuracy: mu = -11.191687732934952
#                               r = 26.87095208093524
#                               on_off = -143.1696753948927
#                               Vt = -48.46687726676464
# On epoch  30
# Total Epoch Testing Loss = 0.14545318484306335
# Total Epoch Testing Accuracy: mu = -10.701733827590942
#                               r = 26.021891087293625
#                               on_off = -145.55011801421642
#                               Vt = -48.52523133158684
# On epoch  31
# Total Epoch Testing Loss = 0.06919597089290619
# Total Epoch Testing Accuracy: mu = -8.80887657403946
#                               r = 25.70483428426087
#                               on_off = -146.0493128746748
#                               Vt = -48.31075817346573
# On epoch  32
# Total Epoch Testing Loss = 0.041382983326911926
# Total Epoch Testing Accuracy: mu = -9.52896885573864
#                               r = 25.536388345062733
#                               on_off = -152.47841030359268
#                               Vt = -48.69232214987278
# On epoch  33
# Total Epoch Testing Loss = 0.06675072759389877
# Total Epoch Testing Accuracy: mu = -9.12417508661747
#                               r = 25.334769184701145
#                               on_off = -153.2479852437973
#                               Vt = -48.671855032444
# On epoch  34
# Total Epoch Testing Loss = 0.16917374730110168
# Total Epoch Testing Accuracy: mu = -9.291785582900047
#                               r = 25.497993733733892
#                               on_off = -156.12693279981613
#                               Vt = -48.86843003332615
# On epoch  35
# Total Epoch Testing Loss = 0.14545318484306335
# Total Epoch Testing Accuracy: mu = -10.243233293294907
#                               r = 25.456002727150917
#                               on_off = -156.32902570068836
#                               Vt = -48.697635158896446
# On epoch  36
# Total Epoch Testing Loss = 0.2901744246482849
# Total Epoch Testing Accuracy: mu = -9.036331623792648
#                               r = 25.399716245010495
#                               on_off = -157.30825811624527
#                               Vt = -48.743175715208054
# On epoch  37
# Total Epoch Testing Loss = 0.11212128400802612
# Total Epoch Testing Accuracy: mu = -8.233020827174187
#                               r = 25.38803038187325
#                               on_off = -159.0126395225525
#                               Vt = -48.450470715761185
# On epoch  38
# Total Epoch Testing Loss = 0.21160611510276794
# Total Epoch Testing Accuracy: mu = -9.207598865032196
#                               r = 25.522732082754374
#                               on_off = -159.8042082041502
#                               Vt = -48.832031711936
# On epoch  39
# Total Epoch Testing Loss = 0.041382983326911926
# Total Epoch Testing Accuracy: mu = -8.505699411034584
#                               r = 25.80056143924594
#                               on_off = -158.66281762719154
#                               Vt = -48.53480942547321
# On epoch  40
# Total Epoch Testing Loss = 0.4313587248325348
# Total Epoch Testing Accuracy: mu = -9.43431369960308
#                               r = 25.925195030868053
#                               on_off = -159.470896422863
#                               Vt = -48.720744624733925
# On epoch  41
# Total Epoch Testing Loss = 0.07039044797420502
# Total Epoch Testing Accuracy: mu = -6.604572013020515
#                               r = 25.588803458958864
#                               on_off = -158.6330097168684
#                               Vt = -48.67136403918266
# On epoch  42
# Total Epoch Testing Loss = 0.06671608984470367
# Total Epoch Testing Accuracy: mu = -7.505083456635475
#                               r = 25.40726028382778
#                               on_off = -159.71574038267136
#                               Vt = -48.445237055420876
# On epoch  43
# Total Epoch Testing Loss = 0.3078838884830475
# Total Epoch Testing Accuracy: mu = -6.817927584052086
#                               r = 24.991951347328722
#                               on_off = -157.97225460410118
#                               Vt = -48.18599224090576
# On epoch  44
# Total Epoch Testing Loss = 0.4303087890148163
# Total Epoch Testing Accuracy: mu = -5.1077185198664665
#                               r = 24.85175299225375
#                               on_off = -157.20257088541985
#                               Vt = -48.103613778948784
# On epoch  45
# Total Epoch Testing Loss = 0.14545318484306335
# Total Epoch Testing Accuracy: mu = -7.568814791738987
#                               r = 25.62683094292879
#                               on_off = -157.92512744665146
#                               Vt = -48.32530990242958
# On epoch  46
# Total Epoch Testing Loss = 0.17979387938976288
# Total Epoch Testing Accuracy: mu = -8.650936000049114
#                               r = 25.84796966984868
#                               on_off = -159.21934321522713
#                               Vt = -48.530587553977966
# On epoch  47
# Total Epoch Testing Loss = 0.4322469234466553
# Total Epoch Testing Accuracy: mu = -7.00764674693346
#                               r = 25.738524412736297
#                               on_off = -159.89463478326797
#                               Vt = -48.18084016442299
# On epoch  48
# Total Epoch Testing Loss = 0.6822601556777954
# Total Epoch Testing Accuracy: mu = -6.304723024368286
#                               r = 25.531742023304105
#                               on_off = -162.02785968780518
#                               Vt = -47.99179881811142
# On epoch  49
# Total Epoch Testing Loss = 0.06620097905397415
# Total Epoch Testing Accuracy: mu = -6.446302123367786
#                               r = 25.857057236135006
#                               on_off = -164.49944376945496
#                               Vt = -47.77044467628002
# On epoch  50
# Total Epoch Testing Loss = 0.1734449416399002
# Total Epoch Testing Accuracy: mu = -7.676406763494015
#                               r = 25.510223722085357
#                               on_off = -162.304075807333
#                               Vt = -47.48232960700989
# On epoch  51
# Total Epoch Testing Loss = 0.06683234125375748
# Total Epoch Testing Accuracy: mu = -9.31733027100563
#                               r = 25.908380560576916
#                               on_off = -161.88617572188377
#                               Vt = -48.0644378811121
# On epoch  52
# Total Epoch Testing Loss = 0.041382983326911926
# Total Epoch Testing Accuracy: mu = -9.363554790616035
#                               r = 26.20173068717122
#                               on_off = -159.94586758315563
#                               Vt = -46.7912957072258
# On epoch  53
# Total Epoch Testing Loss = 0.6475523114204407
# Total Epoch Testing Accuracy: mu = -8.641917631030083
#                               r = 26.148223876953125
#                               on_off = -159.57137309014797
#                               Vt = -46.89505510032177
# On epoch  54
# Total Epoch Testing Loss = 0.06096939742565155
# Total Epoch Testing Accuracy: mu = -6.085066497325897
#                               r = 25.849620439112186
#                               on_off = -159.81921516358852
#                               Vt = -47.205838188529015
# On epoch  55
# Total Epoch Testing Loss = 0.2116740345954895
# Total Epoch Testing Accuracy: mu = -7.068580575287342
#                               r = 25.83447559736669
#                               on_off = -158.40862020850182
#                               Vt = -46.96083478629589
# On epoch  56
# Total Epoch Testing Loss = 0.9342734217643738
# Total Epoch Testing Accuracy: mu = -6.742663681507111
#                               r = 25.249748723581433
#                               on_off = -159.06095542013645
#                               Vt = -47.130122035741806
# On epoch  57
# Total Epoch Testing Loss = 0.06705222278833389
# Total Epoch Testing Accuracy: mu = -7.335412502288818
#                               r = 24.84401655383408
#                               on_off = -158.2166437059641
#                               Vt = -47.4342867732048
# On epoch  58
# Total Epoch Testing Loss = 0.2893245816230774
# Total Epoch Testing Accuracy: mu = -7.834585756063461
#                               r = 25.181414163671434
#                               on_off = -156.98405653238297
#                               Vt = -47.443435713648796
# On epoch  59
# Total Epoch Testing Loss = 0.3053182363510132
# Total Epoch Testing Accuracy: mu = -10.679629817605019
#                               r = 24.92708098143339
#                               on_off = -156.37145191431046
#                               Vt = -47.46103994548321
# On epoch  60
# Total Epoch Testing Loss = 0.041382983326911926
# Total Epoch Testing Accuracy: mu = -11.257662251591682
#                               r = 24.911422899458557
#                               on_off = -156.6303938627243
#                               Vt = -48.00811894237995
# On epoch  61
# Total Epoch Testing Loss = 0.2107613980770111
# Total Epoch Testing Accuracy: mu = -11.311273649334908
#                               r = 25.89574484154582
#                               on_off = -156.0446932911873
#                               Vt = -48.179349675774574
# On epoch  62
# Total Epoch Testing Loss = 0.14276519417762756
# Total Epoch Testing Accuracy: mu = -12.94928751885891
#                               r = 26.314479485154152
#                               on_off = -157.66359269618988
#                               Vt = -47.2952451556921
# On epoch  63
# Total Epoch Testing Loss = 0.12848487496376038
# Total Epoch Testing Accuracy: mu = -12.513157352805138
#                               r = 26.35692935436964
#                               on_off = -159.55043584108353
#                               Vt = -47.64285087585449
# On epoch  64
# Total Epoch Testing Loss = 0.12259122729301453
# Total Epoch Testing Accuracy: mu = -13.004690408706665
#                               r = 26.170057337731123
#                               on_off = -158.39741080999374
#                               Vt = -47.19998612999916
# On epoch  65
# Total Epoch Testing Loss = 0.058132097125053406
# Total Epoch Testing Accuracy: mu = -12.771567702293396
#                               r = 24.849877087399364
#                               on_off = -158.1725925207138
#                               Vt = -47.30565845966339
# On epoch  66
# Total Epoch Testing Loss = 0.057520538568496704
# Total Epoch Testing Accuracy: mu = -10.848193615674973
#                               r = 24.49916759505868
#                               on_off = -158.06376188993454
#                               Vt = -47.43250012397766
# On epoch  67
# Total Epoch Testing Loss = 0.13985282182693481
# Total Epoch Testing Accuracy: mu = -12.844101712107658
#                               r = 24.18249482579995
#                               on_off = -156.657013297081
#                               Vt = -47.367461770772934
# On epoch  68
# Total Epoch Testing Loss = 0.1366664171218872
# Total Epoch Testing Accuracy: mu = -12.786230072379112
#                               r = 24.36920204618218
#                               on_off = -156.20837956666946
#                               Vt = -47.36056700348854
# On epoch  69
# Total Epoch Testing Loss = 0.2160288393497467
# Total Epoch Testing Accuracy: mu = -14.396239817142487
#                               r = 24.788322567474097
#                               on_off = -157.16704279184341
#                               Vt = -47.12308943271637
# On epoch  70
# Total Epoch Testing Loss = 0.43581438064575195
# Total Epoch Testing Accuracy: mu = -14.703385159373283
#                               r = 24.68409223947674
#                               on_off = -159.50152575969696
#                               Vt = -46.7041227966547
# On epoch  71
# Total Epoch Testing Loss = 0.16836538910865784
# Total Epoch Testing Accuracy: mu = -12.484337761998177
#                               r = 25.80147972330451
#                               on_off = -160.01602672040462
#                               Vt = -46.80200405418873
# On epoch  72
# Total Epoch Testing Loss = 0.4295210838317871
# Total Epoch Testing Accuracy: mu = -11.587916687130928
#                               r = 25.60666431672871
#                               on_off = -157.93243646621704
#                               Vt = -46.82056047022343
# On epoch  73
# Total Epoch Testing Loss = 0.05761221796274185
# Total Epoch Testing Accuracy: mu = -12.422550842165947
#                               r = 26.045395899564028
#                               on_off = -158.78353714942932
#                               Vt = -47.02839441597462
# On epoch  74
# Total Epoch Testing Loss = 0.05808080732822418
# Total Epoch Testing Accuracy: mu = -11.807652190327644
#                               r = 26.511332392692566
#                               on_off = -158.34812857210636
#                               Vt = -47.103461250662804
# On epoch  75
# Total Epoch Testing Loss = 0.16695958375930786
# Total Epoch Testing Accuracy: mu = -13.084575906395912
#                               r = 25.396466860547662
#                               on_off = -156.46950751543045
#                               Vt = -46.5552993118763
# On epoch  76
# Total Epoch Testing Loss = 0.43099644780158997
# Total Epoch Testing Accuracy: mu = -15.899328514933586
#                               r = 25.694491900503635
#                               on_off = -159.06836986541748
#                               Vt = -46.525371074676514
# On epoch  77
# Total Epoch Testing Loss = 0.145094633102417
# Total Epoch Testing Accuracy: mu = -14.251989871263504
#                               r = 25.483252899721265
#                               on_off = -157.38374143838882
#                               Vt = -46.66270986199379
# On epoch  78
# Total Epoch Testing Loss = 0.4294666051864624
# Total Epoch Testing Accuracy: mu = -15.951302647590637
#                               r = 25.791332591325045
#                               on_off = -157.02929198741913
#                               Vt = -46.45208902657032
# On epoch  79
# Total Epoch Testing Loss = 0.28373974561691284
# Total Epoch Testing Accuracy: mu = -17.420903593301773
#                               r = 25.71025751531124
#                               on_off = -155.61895221471786
#                               Vt = -47.25457318127155
# On epoch  80
# Total Epoch Testing Loss = 0.30400288105010986
# Total Epoch Testing Accuracy: mu = -19.002623856067657
#                               r = 25.472221011295915
#                               on_off = -155.66434264183044
#                               Vt = -46.77425101399422
# On epoch  81
# Total Epoch Testing Loss = 0.5795261859893799
# Total Epoch Testing Accuracy: mu = -18.470388650894165
#                               r = 25.471623614430428
#                               on_off = -155.37129640579224
#                               Vt = -46.98508754372597
# On epoch  82
# Total Epoch Testing Loss = 0.06919597089290619
# Total Epoch Testing Accuracy: mu = -18.620699271559715
#                               r = 26.12033039331436
#                               on_off = -157.4371039867401
#                               Vt = -46.39222398400307
# On epoch  83
# Total Epoch Testing Loss = 0.15238939225673676
# Total Epoch Testing Accuracy: mu = -20.513195917010307
#                               r = 26.365841925144196
#                               on_off = -155.52963018417358
#                               Vt = -46.555352956056595
# On epoch  84
# Total Epoch Testing Loss = 0.14545318484306335
# Total Epoch Testing Accuracy: mu = -17.1249832957983
#                               r = 26.35974558070302
#                               on_off = -154.82762604951859
#                               Vt = -46.483153849840164
# On epoch  85
# Total Epoch Testing Loss = 0.14545318484306335
# Total Epoch Testing Accuracy: mu = -16.58722646534443
#                               r = 26.50972967967391
#                               on_off = -155.77432811260223
#                               Vt = -45.92135772109032
# On epoch  86
# Total Epoch Testing Loss = 0.06548037379980087
# Total Epoch Testing Accuracy: mu = -16.319872438907623
#                               r = 27.169501595199108
#                               on_off = -155.4514229297638
#                               Vt = -46.93724103271961
# On epoch  87
# Total Epoch Testing Loss = 0.07393134385347366
# Total Epoch Testing Accuracy: mu = -15.261925011873245
#                               r = 27.315662149339914
#                               on_off = -156.55743777751923
#                               Vt = -47.15227596461773
# On epoch  88
# Total Epoch Testing Loss = 0.1486830711364746
# Total Epoch Testing Accuracy: mu = -15.396497026085854
#                               r = 27.371493726968765
#                               on_off = -157.77896642684937
#                               Vt = -46.34743630886078
# On epoch  89
# Total Epoch Testing Loss = 0.06374882161617279
# Total Epoch Testing Accuracy: mu = -16.36320911347866
#                               r = 27.320539578795433
#                               on_off = -159.29079800844193
#                               Vt = -46.313611790537834
# On epoch  90
# Total Epoch Testing Loss = 0.20825880765914917
# Total Epoch Testing Accuracy: mu = -16.42158553004265
#                               r = 27.186900284141302
#                               on_off = -155.76450377702713
#                               Vt = -46.38528935611248
# On epoch  91
# Total Epoch Testing Loss = 0.27546408772468567
# Total Epoch Testing Accuracy: mu = -16.872717440128326
#                               r = 27.054487075656652
#                               on_off = -153.28036099672318
#                               Vt = -46.330299600958824
# On epoch  92
# Total Epoch Testing Loss = 0.12263640761375427
# Total Epoch Testing Accuracy: mu = -17.95927733182907
#                               r = 27.462197467684746
#                               on_off = -152.64200568199158
#                               Vt = -46.687328070402145
# On epoch  93
# Total Epoch Testing Loss = 0.5068192481994629
# Total Epoch Testing Accuracy: mu = -21.067599952220917
#                               r = 26.71575639396906
#                               on_off = -152.51541882753372
#                               Vt = -46.51341773569584
# On epoch  94
# Total Epoch Testing Loss = 0.2991749048233032
# Total Epoch Testing Accuracy: mu = -20.54043300449848
#                               r = 26.83787839487195
#                               on_off = -155.5685207247734
#                               Vt = -46.27087637782097
# On epoch  95
# Total Epoch Testing Loss = 0.15206493437290192
# Total Epoch Testing Accuracy: mu = -20.593606680631638
#                               r = 27.054282184690237
#                               on_off = -155.37922084331512
#                               Vt = -46.79419733583927
# On epoch  96
# Total Epoch Testing Loss = 0.05695850029587746
# Total Epoch Testing Accuracy: mu = -23.182589933276176
#                               r = 26.809909101575613
#                               on_off = -155.65527975559235
#                               Vt = -46.913183480501175
# On epoch  97
# Total Epoch Testing Loss = 0.9665733575820923
# Total Epoch Testing Accuracy: mu = -22.880257666110992
#                               r = 27.827063761651516
#                               on_off = -154.52812165021896
#                               Vt = -46.848705783486366
# On epoch  98
# Total Epoch Testing Loss = 0.20572373270988464
# Total Epoch Testing Accuracy: mu = -24.119297973811626
#                               r = 27.43934951722622
#                               on_off = -153.60167324543
#                               Vt = -46.6496005654335
# On epoch  99
# Total Epoch Testing Loss = 0.0617886558175087
# Total Epoch Testing Accuracy: mu = -24.000167474150658
#                               r = 27.39991880953312
#                               on_off = -153.66954505443573
#                               Vt = -46.39292433857918

# %%
epochs = np.arange(1, (num_epochs+1), 1)

nuts.plot_OFET_df_loss(epochs, train_epoch_losses, test_epoch_losses,
                       mu_train_epoch_losses, mu_test_epoch_losses,
                       r_train_epoch_losses, r_test_epoch_losses,
                       on_off_train_epoch_losses, on_off_test_epoch_losses,
                       vt_train_epoch_losses, vt_test_epoch_losses)

nuts.plot_OFET_df_accuracies(epochs, mu_test_epoch_accuracies, r_test_epoch_accuracies, 
                             on_off_test_epoch_accuracies, vt_test_epoch_accuracies)

# %%
model.eval()

with torch.no_grad():
    for inputs, mu_labels, r_labels, on_off_labels, vt_labels in testing_data_set:
        inputs = inputs.to(device)
        mu_labels = mu_labels.to(device)
        r_labels = r_labels.to(device)
        on_off_labels = on_off_labels.to(device)
        vt_labels = vt_labels.to(device)

        mu_out, r_out, on_off_out, vt_out = model(inputs)

# %%
# %autoreload
nuts.plot_OFET_parity(mu_labels, mu_out, r_labels, r_out,
                      on_off_labels, on_off_out, vt_labels, vt_out)
