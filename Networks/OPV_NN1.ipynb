# %%
# %load_ext autoreload

import os
import sys
import glob

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

import torch
import torch.nn as nn

module_path = os.path.abspath(os.path.join('../m2py/networks/'))
if module_path not in sys.path:
    sys.path.append(module_path)
import morphology_networks as net
import model_training as train
import model_testing as test
import physically_informed_loss_functions as PhysLoss
import network_utils as nuts

torch.manual_seed(28)

# %% [markdown]
# # This notebook seeks to use all OPV processing conditions and morphological descriptors to predict device performance.
#
# ## There will be 3 Neural Networks outlined, each with similar architecture, but varying inputs. This first NN will only use processing conditions to try to predict performance
#
# ### Inputs:
# - DataFrame containing device processing conditions and their subsequent performance.
#
# *_Note:_* This DataFrame will only contain devices with reasonable performance values.
#
# ### Outputs:
# - Tensor of predicted performance for given processing conditions

# %%
#Take in data as a dataframe for easy preprocessing
device_df = pd.read_excel('/Users/wesleytatum/Desktop/OPV_device_df.xlsx')
print (device_df.shape)
device_df.head()
# Out:
# (366, 11)
#    Unnamed: 0  Unnamed: 0.1                        File Name  Time (min)  \
# 0           0           291  2019_4_16_P3HTPCBM_NA_3000_SUB1           0
# 1           1           283  2019_4_16_P3HTPCBM_NA_1000_SUB7           0
# 2           2           284  2019_4_16_P3HTPCBM_NA_1000_SUB7           0
# 3           3           280  2019_4_16_P3HTPCBM_NA_1000_SUB7           0
# 4           4           287  2019_4_16_P3HTPCBM_NA_3000_SUB1           0
#
#    Device  Temp (C)       PCE      VocL       Jsc         FF  Substrate
# 0       5         0  0.053196  0.088773  2.319470  25.835041          1
# 1       5         0  0.323514  0.706579  2.021489  22.649638          7
# 2       6         0  0.620043  0.665916  1.867738  49.852415          7
# 3       2         0  0.628255  0.654254  1.915640  50.127434          7
# 4       1         0  0.637683  0.662407  2.204954  43.659713          1

# %%
# Hyper parameters
num_epochs = 50
batch_size = int(len(device_df['PCE'])*0.8*0.5) # 50% of x_train samples
learning_rate = 0.00083

# Device configuration (GPU if available, otherwise CPU)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
X = device_df[['Time (min)', 'Temp (C)']] #input features used to make prediction
Y = device_df[['PCE', 'VocL', 'Jsc', 'FF']] #target features to be predicted

x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, shuffle = True) #split dataset into separate testing and training datasets

# %%
x_train, x_train_key = nuts.df_normalizer(x_train)
y_train, y_train_key = nuts.df_normalizer(y_train)

x_test, x_test_key = nuts.df_normalizer(x_test)
y_test, y_test_key = nuts.df_normalizer(y_test)

pce_train = y_train['PCE']
pce_test = y_test['PCE']
voc_train = y_train['VocL']
voc_test = y_test['VocL']
jsc_train = y_train['Jsc']
jsc_test = y_test['Jsc']
ff_train = y_train['FF']
ff_test = y_test['FF']

x_train_tensor = torch.tensor(x_train.values.astype(np.float32)) #convert pd.DataFrame -> np.ndarray -> torch.tensor
pce_train_tensor = torch.tensor(pce_train.values.astype(np.float32))
voc_train_tensor = torch.tensor(voc_train.values.astype(np.float32))
jsc_train_tensor = torch.tensor(jsc_train.values.astype(np.float32))
ff_train_tensor = torch.tensor(ff_train.values.astype(np.float32))

#create tensor with features and targets
train_tensor = torch.utils.data.TensorDataset(x_train_tensor, pce_train_tensor, voc_train_tensor, jsc_train_tensor, ff_train_tensor)
#create iterable dataset with batches
training_data_set = torch.utils.data.DataLoader(dataset = train_tensor, batch_size = batch_size, shuffle = True)

x_test_tensor = torch.tensor(x_test.values.astype(np.float32))
pce_test_tensor = torch.tensor(pce_test.values.astype(np.float32))
voc_test_tensor = torch.tensor(voc_test.values.astype(np.float32))
jsc_test_tensor = torch.tensor(jsc_test.values.astype(np.float32))
ff_test_tensor = torch.tensor(ff_test.values.astype(np.float32))

test_tensor = torch.utils.data.TensorDataset(x_test_tensor, pce_test_tensor, voc_test_tensor, jsc_test_tensor, ff_test_tensor)
testing_data_set = torch.utils.data.DataLoader(dataset = test_tensor, batch_size = batch_size, shuffle = True)

# %% [markdown]
# Now that the data, model, training, and evaluating are all set up, let's actually use everything

# %%
# Instantiate our beautiful NN model
# takes in 2 features (anneal time, anneal temp) 
# predicts 4 metrics (PCE, Voc, Jsc, FF)
in_dims = int(x_train_tensor.size(1)) #number of x channels
out_dims = y_test.shape[1] #number of predicted features

model = net.OPV_df_NN(in_dims = in_dims, out_dims = out_dims).to(device)

#define the optimizer
optimizer = torch.optim.Adam(params = model.parameters(), lr = learning_rate)

# %%
# %autoreload

#empty list to hold loss per epoch
train_epoch_losses = []
pce_train_epoch_losses = []
voc_train_epoch_losses = []
jsc_train_epoch_losses = []
ff_train_epoch_losses = []

test_epoch_losses = []
pce_test_epoch_losses = []
voc_test_epoch_losses = []
jsc_test_epoch_losses = []
ff_test_epoch_losses = []

pce_test_epoch_accuracies = []
voc_test_epoch_accuracies = []
jsc_test_epoch_accuracies = []
ff_test_epoch_accuracies = []

save_epochs = np.arange(0, num_epochs, 5)

for epoch in range(num_epochs):
    print('On epoch ', epoch)
    
    save_dir = "/Users/wesleytatum/Desktop/model_states/OPV_NN1/"
    model_name = "OPV_NN1"
    model_path = save_dir+model_name+'*.pt'
    if epoch < 10:
        save_path = save_dir + model_name + '_epoch0' + str(epoch) + '.pt'
    else:
        save_path = save_dir + model_name + '_epoch' + str(epoch) + '.pt'
        
#     if glob.glob(model_path) != []:
#         model_states = glob.glob(model_path)
#         model_states = sorted(model_states)
#         previous_model = model_states[-1]
        
#         model, optimizer = nuts.load_trained_model(previous_model, model, optimizer)
    
    model, train_loss, pce_train_loss, voc_train_loss, jsc_train_loss, ff_train_loss = train.train_OPV_df_model(model = model,
                                                                                                         training_data_set = training_data_set,
                                                                                                         optimizer = optimizer)
    train_epoch_losses.append(train_loss)
    pce_train_epoch_losses.append(pce_train_loss)
    voc_train_epoch_losses.append(voc_train_loss)
    jsc_train_epoch_losses.append(jsc_train_loss)
    ff_train_epoch_losses.append(ff_train_loss)
    
    test_loss, pce_test_loss, voc_test_loss, jsc_test_loss, ff_test_loss, pce_acc, voc_acc, jsc_acc, ff_acc = test.eval_OPV_df_model(model = model,
                                                                                                                                    testing_data_set = testing_data_set)
    test_epoch_losses.append(test_loss)
    pce_test_epoch_losses.append(pce_test_loss)
    voc_test_epoch_losses.append(voc_test_loss)
    jsc_test_epoch_losses.append(jsc_test_loss)
    ff_test_epoch_losses.append(ff_test_loss)
    
    pce_test_epoch_accuracies.append(pce_acc)
    voc_test_epoch_accuracies.append(voc_acc)
    jsc_test_epoch_accuracies.append(jsc_acc)
    ff_test_epoch_accuracies.append(ff_acc)
    
    if epoch in save_epochs:
 
        nuts.save_trained_model(save_path, epoch, model, optimizer, train_loss, test_loss)
        #TODO: update for branched OPV specific function?
# Out:
# On epoch  0
# Total Epoch Testing Loss = 0.03441852331161499
# Total Epoch Testing Accuracy: PCE = 246.912034540563
#                               Voc = 135.51889206912065
#                               Jsc = 166.410104648487
#                               FF = 53.141348012974746
# On epoch  1
# Total Epoch Testing Loss = 0.017627565190196037
# Total Epoch Testing Accuracy: PCE = 235.7155339943396
#                               Voc = 126.92271777101465
#                               Jsc = 159.55047502711014
#                               FF = 51.951066200696935
# On epoch  2
# Total Epoch Testing Loss = 0.05739165470004082
# Total Epoch Testing Accuracy: PCE = 224.96844280410454
#                               Voc = 118.31006133878552
#                               Jsc = 152.96436290483217
#                               FF = 51.20000305610735
# On epoch  3
# Total Epoch Testing Loss = 0.05766863003373146
# Total Epoch Testing Accuracy: PCE = 214.48669506085886
#                               Voc = 109.63269375466011
#                               Jsc = 146.74547532120266
#                               FF = 50.559985609976835
# On epoch  4
# Total Epoch Testing Loss = 0.010480915196239948
# Total Epoch Testing Accuracy: PCE = 204.05481216069816
#                               Voc = 100.56057411271173
#                               Jsc = 140.1749233136306
#                               FF = 50.03305127391139
# On epoch  5
# Total Epoch Testing Loss = 0.008656649850308895
# Total Epoch Testing Accuracy: PCE = 193.8778803960697
#                               Voc = 93.86180437899925
#                               Jsc = 133.59401153551568
#                               FF = 49.729239442259875
# On epoch  6
# Total Epoch Testing Loss = 0.045432332903146744
# Total Epoch Testing Accuracy: PCE = 183.6978493510066
#                               Voc = 84.17423983683457
#                               Jsc = 126.92357962195938
#                               FF = 49.77895889330555
# On epoch  7
# Total Epoch Testing Loss = 0.030657798051834106
# Total Epoch Testing Accuracy: PCE = 173.23668623292767
#                               Voc = 74.27157519032826
#                               Jsc = 119.92963407490704
#                               FF = 49.85614947571948
# On epoch  8
# Total Epoch Testing Loss = 0.03887275978922844
# Total Epoch Testing Accuracy: PCE = 162.64260048801836
#                               Voc = 65.41883189835258
#                               Jsc = 112.68432454482928
#                               FF = 49.942179381646014
# On epoch  9
# Total Epoch Testing Loss = 0.018162470310926437
# Total Epoch Testing Accuracy: PCE = 151.62946678496695
#                               Voc = 59.62275125690408
#                               Jsc = 105.26809934023265
#                               FF = 50.094142500814556
# On epoch  10
# Total Epoch Testing Loss = 0.003662694711238146
# Total Epoch Testing Accuracy: PCE = 139.98576128805004
#                               Voc = 54.55141085627917
#                               Jsc = 100.84921290745605
#                               FF = 50.724383212021884
# On epoch  11
# Total Epoch Testing Loss = 0.022863268852233887
# Total Epoch Testing Accuracy: PCE = 128.38885864695987
#                               Voc = 49.1408635988026
#                               Jsc = 92.93306878944104
#                               FF = 51.99096911158916
# On epoch  12
# Total Epoch Testing Loss = 0.012514970265328884
# Total Epoch Testing Accuracy: PCE = 115.96137172467
#                               Voc = 43.99707392361519
#                               Jsc = 87.71807617835097
#                               FF = 54.02437879647305
# On epoch  13
# Total Epoch Testing Loss = 0.020000183954834938
# Total Epoch Testing Accuracy: PCE = 102.962829937806
#                               Voc = 39.397708739380576
#                               Jsc = 82.92274320045033
#                               FF = 56.53756494559914
# On epoch  14
# Total Epoch Testing Loss = 0.01988586224615574
# Total Epoch Testing Accuracy: PCE = 92.24837078033266
#                               Voc = 35.614291174538636
#                               Jsc = 78.49123244350021
#                               FF = 58.025521332849564
# On epoch  15
# Total Epoch Testing Loss = 0.005488440860062838
# Total Epoch Testing Accuracy: PCE = 81.74211054637625
#                               Voc = 35.64240254502668
#                               Jsc = 73.78753761987429
#                               FF = 58.188807380045894
# On epoch  16
# Total Epoch Testing Loss = 0.011052417568862438
# Total Epoch Testing Accuracy: PCE = 72.44079155293672
#                               Voc = 43.113775376381504
#                               Jsc = 68.99882896325073
#                               FF = 57.20989049413884
# On epoch  17
# Total Epoch Testing Loss = 0.003850345965474844
# Total Epoch Testing Accuracy: PCE = 65.05531970210173
#                               Voc = 53.22272692731506
#                               Jsc = 66.14074252948568
#                               FF = 56.18246042993977
# On epoch  18
# Total Epoch Testing Loss = 0.008533693850040436
# Total Epoch Testing Accuracy: PCE = 62.421632906606085
#                               Voc = 63.79678949613024
#                               Jsc = 64.55749839141562
#                               FF = 54.948048369103184
# On epoch  19
# Total Epoch Testing Loss = 0.010248234495520592
# Total Epoch Testing Accuracy: PCE = 61.441553581814354
#                               Voc = 71.37708662178468
#                               Jsc = 63.02840050209213
#                               FF = 53.81691002230337
# On epoch  20
# Total Epoch Testing Loss = 0.006884738337248564
# Total Epoch Testing Accuracy: PCE = 62.76918023925375
#                               Voc = 74.34630805399973
#                               Jsc = 61.57082027025722
#                               FF = 52.27121338499961
# On epoch  21
# Total Epoch Testing Loss = 0.006522344890981913
# Total Epoch Testing Accuracy: PCE = 65.40861726373535
#                               Voc = 74.07559392992658
#                               Jsc = 60.210083022310926
#                               FF = 51.57633200287819
# On epoch  22
# Total Epoch Testing Loss = 0.004434096626937389
# Total Epoch Testing Accuracy: PCE = 68.88684764806483
#                               Voc = 74.5112371538149
#                               Jsc = 59.24791133383641
#                               FF = 51.215668450537564
# On epoch  23
# Total Epoch Testing Loss = 0.0010369073133915663
# Total Epoch Testing Accuracy: PCE = 72.65049044193852
#                               Voc = 72.90301030199673
#                               Jsc = 58.66147254002154
#                               FF = 50.8843477887756
# On epoch  24
# Total Epoch Testing Loss = 0.006888378411531448
# Total Epoch Testing Accuracy: PCE = 76.66642516662644
#                               Voc = 72.03463611973298
#                               Jsc = 58.63679961955829
#                               FF = 50.751253880711424
# On epoch  25
# Total Epoch Testing Loss = 0.009584005922079086
# Total Epoch Testing Accuracy: PCE = 80.7174163415471
#                               Voc = 67.98260404438888
#                               Jsc = 59.40153016079519
#                               FF = 50.73698906611802
# On epoch  26
# Total Epoch Testing Loss = 0.002496531466022134
# Total Epoch Testing Accuracy: PCE = 82.97609740905966
#                               Voc = 64.44883528794792
#                               Jsc = 60.77780219493434
#                               FF = 50.69514008591304
# On epoch  27
# Total Epoch Testing Loss = 0.001310874940827489
# Total Epoch Testing Accuracy: PCE = 81.01828847099347
#                               Voc = 59.22830032335745
#                               Jsc = 61.8704668328015
#                               FF = 50.413490617899484
# On epoch  28
# Total Epoch Testing Loss = 0.0025660288520157337
# Total Epoch Testing Accuracy: PCE = 76.0195553258716
#                               Voc = 52.61081507511286
#                               Jsc = 62.14147062588332
#                               FF = 49.93314039279908
# On epoch  29
# Total Epoch Testing Loss = 0.004188516177237034
# Total Epoch Testing Accuracy: PCE = 72.22062518971192
#                               Voc = 46.382188960293156
#                               Jsc = 62.73568312675264
#                               FF = 49.80327053423467
# On epoch  30
# Total Epoch Testing Loss = 0.002285358030349016
# Total Epoch Testing Accuracy: PCE = 69.82012332568097
#                               Voc = 41.644451574334326
#                               Jsc = 63.652226646946794
#                               FF = 49.746074451360144
# On epoch  31
# Total Epoch Testing Loss = 0.0018194415606558323
# Total Epoch Testing Accuracy: PCE = 68.58503081508584
#                               Voc = 39.17413420819463
#                               Jsc = 64.55386380312612
#                               FF = 49.72499397998625
# On epoch  32
# Total Epoch Testing Loss = 0.0017219181172549725
# Total Epoch Testing Accuracy: PCE = 68.0912314687629
#                               Voc = 37.90602700979876
#                               Jsc = 65.74227967286936
#                               FF = 49.751420144142735
# On epoch  33
# Total Epoch Testing Loss = 0.007584830280393362
# Total Epoch Testing Accuracy: PCE = 67.92673797824898
#                               Voc = 37.70703321725533
#                               Jsc = 66.43134217860329
#                               FF = 49.78990171457062
# On epoch  34
# Total Epoch Testing Loss = 0.0012777764350175858
# Total Epoch Testing Accuracy: PCE = 68.12528312911053
#                               Voc = 38.038236057429856
#                               Jsc = 67.48525799075897
#                               FF = 49.801533704472554
# On epoch  35
# Total Epoch Testing Loss = 0.0039976066909730434
# Total Epoch Testing Accuracy: PCE = 68.57793827012584
#                               Voc = 39.171516363716655
#                               Jsc = 66.72384145896177
#                               FF = 49.839866378130644
# On epoch  36
# Total Epoch Testing Loss = 0.0030206500086933374
# Total Epoch Testing Accuracy: PCE = 69.19706021057995
#                               Voc = 41.60296635212993
#                               Jsc = 66.19015860471976
#                               FF = 49.87914636762611
# On epoch  37
# Total Epoch Testing Loss = 0.002856446197256446
# Total Epoch Testing Accuracy: PCE = 70.53948812992186
#                               Voc = 44.43037164337757
#                               Jsc = 65.5399455437185
#                               FF = 49.95671185457173
# On epoch  38
# Total Epoch Testing Loss = 0.005724032409489155
# Total Epoch Testing Accuracy: PCE = 72.37009028526576
#                               Voc = 47.444206340288794
#                               Jsc = 64.97623207286705
#                               FF = 50.116748571894576
# On epoch  39
# Total Epoch Testing Loss = 0.0007288201013579965
# Total Epoch Testing Accuracy: PCE = 74.66634576133376
#                               Voc = 50.877969454017446
#                               Jsc = 64.37140912328047
#                               FF = 50.394875672016596
# On epoch  40
# Total Epoch Testing Loss = 0.009259841404855251
# Total Epoch Testing Accuracy: PCE = 76.36931334068446
#                               Voc = 54.45972117972938
#                               Jsc = 63.82646944147308
#                               FF = 50.51013211266616
# On epoch  41
# Total Epoch Testing Loss = 0.0031746667809784412
# Total Epoch Testing Accuracy: PCE = 77.19599982421543
#                               Voc = 58.00625303810513
#                               Jsc = 63.16252488995323
#                               FF = 50.68429199714415
# On epoch  42
# Total Epoch Testing Loss = 0.0028596455231308937
# Total Epoch Testing Accuracy: PCE = 77.87055736407638
#                               Voc = 61.04369189942608
#                               Jsc = 62.27584520269915
#                               FF = 51.048645766363855
# On epoch  43
# Total Epoch Testing Loss = 0.006589008495211601
# Total Epoch Testing Accuracy: PCE = 78.27501823855062
#                               Voc = 64.34699604287744
#                               Jsc = 60.8838162233902
#                               FF = 51.61940869623544
# On epoch  44
# Total Epoch Testing Loss = 0.010365194641053677
# Total Epoch Testing Accuracy: PCE = 78.57520305834761
#                               Voc = 66.81313486053998
#                               Jsc = 60.02125696946137
#                               FF = 51.83625346603426
# On epoch  45
# Total Epoch Testing Loss = 0.005860883742570877
# Total Epoch Testing Accuracy: PCE = 79.3077860581311
#                               Voc = 67.54719007499138
#                               Jsc = 59.543197152418756
#                               FF = 52.19914658574035
# On epoch  46
# Total Epoch Testing Loss = 0.0031191008165478706
# Total Epoch Testing Accuracy: PCE = 80.70752143457129
#                               Voc = 68.22201268294373
#                               Jsc = 59.30352350822776
#                               FF = 52.313180205198265
# On epoch  47
# Total Epoch Testing Loss = 0.007831338793039322
# Total Epoch Testing Accuracy: PCE = 82.77879889009873
#                               Voc = 69.971521115371
#                               Jsc = 59.20165546892865
#                               FF = 52.67009142584897
# On epoch  48
# Total Epoch Testing Loss = 0.0028038870077580214
# Total Epoch Testing Accuracy: PCE = 85.39149289875215
#                               Voc = 72.24794870015938
#                               Jsc = 59.20739160296885
#                               FF = 53.15468304136114
# On epoch  49
# Total Epoch Testing Loss = 0.017225483432412148
# Total Epoch Testing Accuracy: PCE = 88.10062795744523
#                               Voc = 72.7977160465073
#                               Jsc = 59.29678783223436
#                               FF = 53.41437569806805

# %%
epochs = np.arange(1, (num_epochs+1), 1)

nuts.plot_OPV_df_loss(epochs, train_epoch_losses, test_epoch_losses,
                     pce_train_epoch_losses, pce_test_epoch_losses,
                     voc_train_epoch_losses, voc_test_epoch_losses,
                     jsc_train_epoch_losses, jsc_test_epoch_losses,
                     ff_train_epoch_losses, ff_test_epoch_losses)

nuts.plot_OPV_df_accuracies(epochs, pce_test_epoch_accuracies, voc_test_epoch_accuracies, 
                           jsc_test_epoch_accuracies, ff_test_epoch_accuracies)

# %%
model.eval()

with torch.no_grad():
    for inputs, pce_labels, voc_labels, jsc_labels, ff_labels in testing_data_set:
        inputs = inputs.to(device)
        pce_labels = pce_labels.to(device)
        voc_labels = voc_labels.to(device)
        jsc_labels = jsc_labels.to(device)
        ff_labels = ff_labels.to(device)

        PCE_out, Voc_out, Jsc_out, FF_out = model(inputs)

# %%
nuts.plot_OPV_parity(pce_labels, PCE_out, voc_labels, Voc_out,
                    jsc_labels, Jsc_out, ff_labels, FF_out)
